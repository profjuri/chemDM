# %%
import chemistry_vae_symmetric
import chemistry_vae_selfies
import data_loader
import torch
import importlib
import yaml
import importlib

# %%
# tarin the VAE with RNN decoder 
#reimport chmistry_vae in case of changes
importlib.reload(chemistry_vae_selfies)
# run training model
chemistry_vae_selfies.main()
# Out:
# --> Acquiring data...
# Finished acquiring data.
# Representation: SELFIES
# --> Translating SMILES to SELFIES...
# Finished translating SMILES to SELFIES.
# selfies aplhabet: ['[#Branch2]', '[Ring2]', '[Branch2]', '[=Branch2]', '[O]', '[=O]', '[=C]', '[=N]', '[#Branch1]', '[=Branch1]', '[nop]', '[N]', '[Branch1]', '[F]', '[#C]', '[#N]', '[Ring1]', '[C]']
# smiles aplhabet: ['1', 'F', '3', '#', 'N', 'C', '(', ')', '4', '5', '2', 'O', '=', ' ']
# --> Creating one-hot encoding...
# Finished creating one-hot encoding.
#
# Alphabet has 18 letters, largest molecule is 21 letters.
# random start point de/coder
# *************** : --> cpu
# start training
# num_epochs:  5000
# Epoch: 0,  Batch: 0 / 347,	(loss: 2.9044	| ELAPSED TIME: 0.14717
# Epoch: 0,  Batch: 30 / 347,	(loss: 1.6311	| ELAPSED TIME: 0.58942
# Epoch: 0,  Batch: 60 / 347,	(loss: 1.3053	| ELAPSED TIME: 0.55917
# Epoch: 0,  Batch: 90 / 347,	(loss: 1.2528	| ELAPSED TIME: 0.54265
# ...

# %%
# train symmetric VAE
importlib.reload(chemistry_vae_symmetric)
chemistry_vae_symmetric.main()
# Out:
# --> Acquiring data...
# Finished acquiring data.
# Representation: SELFIES
# --> Translating SMILES to SELFIES...
# Finished translating SMILES to SELFIES.
# selfies alphabet: ['[O]', '[F]', '[=N]', '[C]', '[=Branch2]', '[#N]', '[nop]', '[=O]', '[Ring2]', '[=Branch1]', '[#Branch2]', '[#C]', '[N]', '[Ring1]', '[=C]', '[#Branch1]', '[Branch2]', '[Branch1]']
# smiles alphabet: ['2', '3', 'F', '=', '1', ')', 'N', '5', '(', 'O', 'C', '#', '4', ' ']
# --> Creating one-hot encoding...
# Finished creating one-hot encoding.
#
# Alphabet has 18 letters, largest molecule is 21 letters.
# *************** : --> cpu
# start training
# num_epochs:  100000
# Epoch: 0,  Batch: 0 / 625,	(loss: 0.7124	| ELAPSED TIME: 0.00531
# Epoch: 0,  Batch: 30 / 625,	(loss: 0.1740	| ELAPSED TIME: 0.11611
# Epoch: 0,  Batch: 60 / 625,	(loss: 0.1181	| ELAPSED TIME: 0.10402
# Epoch: 0,  Batch: 90 / 625,	(loss: 0.1107	| ELAPSED TIME: 0.10344
# Epoch: 0,  Batch: 120 / 625,	(loss: 0.1099	| ELAPSED TIME: 0.12103
# ...
