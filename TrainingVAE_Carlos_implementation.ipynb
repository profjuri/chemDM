# %% [markdown]
# ****This notebook simply calls the main method of the VAE python script in order to train the model.****

# %%
#import chemistry_vae_symmetric as vae
import chemistry_vae_selfies_carlos as vae
import data_loader_carlos
import torch
import importlib
import yaml

# %%
#reimport chmistry_vae in case of changes
importlib.reload(vae)
# run training model
vae.main()
# Out:
# --> Acquiring data...
# Finished acquiring data.
# Representation: SELFIES
# --> Translating SMILES to SELFIES...
# Finished translating SMILES to SELFIES.
# selfies aplhabet: ['[=Branch1]', '[C]', '[#Branch1]', '[=N]', '[#C]', '[Ring1]', '[Ring2]', '[Branch2]', '[#Branch2]', '[=Branch2]', '[=C]', '[nop]', '[N]', '[#N]', '[=O]', '[Branch1]', '[O]', '[F]']
# smiles aplhabet: ['N', 'C', 'O', ')', 'F', '5', '(', '=', '#', '4', '1', '3', '2', ' ']
# --> Creating one-hot encoding...
# Finished creating one-hot encoding.
#
# Alphabet has 18 letters, largest molecule is 21 letters.
# random start point de/coder
# *************** : --> cuda
# start training
# num_epochs:  500
# Epoch: 0,  Batch: 0 / 264,	(loss: 2.8868	| ELAPSED TIME: 0.01182
# Epoch: 0,  Batch: 50 / 264,	(loss: 1.5102	| ELAPSED TIME: 0.46809
# Epoch: 0,  Batch: 100 / 264,	(loss: 1.3604	| ELAPSED TIME: 0.44285
# Epoch: 0,  Batch: 150 / 264,	(loss: 1.2521	| ELAPSED TIME: 0.44163
# ...
